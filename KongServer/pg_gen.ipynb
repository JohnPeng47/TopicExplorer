# %%
import sys
sys.path.append("../../../../")
import openai
import json
from langchain import OpenAI, PromptTemplate, LLMChain
from src.server.llm.generators import generate_subtree
from src.KongBot.bot.base import KnowledgeGraph

# Set your API key (replace 'YOUR_API_KEY' with your actual API key)
api_key = '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'

model = OpenAI(
    model_name="gpt-3.5-turbo-0613",
    temperature=0.7,
    openai_api_key="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"
)

gpt4 = OpenAI(
    model_name="gpt-4",
    temperature=0.7,
    openai_api_key="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"
)

# original
# Specify the prompt or text you want to generate from
prompt = PromptTemplate(template="""
You are given a tree, generate a Wikipedia entry for it

Here is the framing context. One sentence should be generated to connect the main content
to the context:
> A modern history of argentina
--> Era of Dictatorships
----> Rise of Juan Perón and Peronism
------> Background to the coup and its reasons
--------> Rise of political opposition
----------> Influence of the Church and religious groups
------------> Church's stance on Peronism and the government
Here is the topic for the main content. Dedicate most of the paragraph to this:
----> Church's role in the post-Peronist era

Here are some requirements:
- Dense Facts: Should contain explicit references to maximum facts
- Terse: Prose terse
- No Section headings
- Generated entry should be in the style of wikipedia                        
Now go generate it:
""", input_variables=[])

# kg = KnowledgeGraph.load_graph("2d7581e1-306a-4fc6-8cd8-93560c027b6b")
# ancestor_tree, subtree, _ = kg.display_tree_v2_lineage()

# print(ancestor_tree)
# print(subtree)
# print(current)

llm = LLMChain(llm=model, prompt=prompt)
res = llm.run({})
print(res)
# Out:
# The Church's role in the post-Peronist era in Argentina was a significant aspect of the country's modern history. Following the fall of Juan Perón's government, the Church played a crucial role in shaping the political landscape and influencing public opinion. During this period, the Church emerged as a prominent voice in opposing the Peronist ideology and its implementation. One of the main reasons for the Church's opposition was its concern over the government's interference in religious matters and the erosion of its traditional influence. The Church viewed Peronism as a threat to its autonomy and sought to protect its role as a moral authority within Argentine society. Despite facing repression and restrictions under the Peronist regime, the Church remained resilient and steadfast in its opposition. It actively engaged in political activism, organizing protests, and encouraging its followers to resist the government's policies. The Church's stance on Peronism and the government p
# ...
